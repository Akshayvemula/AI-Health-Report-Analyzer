# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash")

# %%
with open ( "blood_work.txt", "r") as f:
    blood_work = f.read()

print(blood_work[:200])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL          (Normal: 13.5–17.5)
# Hematocrit:        44%

# %%
extraction_prompt = f"""

You are a medical data extraction assistant.

From the blood report below, extract ALL test values and classify each one as HIGH, LOW, or NORMAL based on the reference ranges provided.

Format your response as:

Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range

Blood Report:

{blood_work}

"""

extraction_response = llm.invoke(extraction_prompt)

extracted_values = extraction_response.content

print("=== STAGE 1: EXTRACTED VALUES ===")

print(extracted_values)
# Out:
# === STAGE 1: EXTRACTED VALUES ===
# Here are the extracted test values and their classifications:
#
# Hemoglobin: 15.1 g/dL | Status: NORMAL | Reference: 13.5–17.5
# Hematocrit: 44% | Status: NORMAL | Reference: 41–53%
# WBC: 6.8 x10^3/uL | Status: NORMAL | Reference: 4.5–11.0
# Platelets: 220 x10^3/uL | Status: NORMAL | Reference: 150–400
# Total Cholesterol: 238 mg/dL | Status: HIGH | Reference: <200
# LDL Cholesterol: 162 mg/dL | Status: HIGH | Reference: <100
# HDL Cholesterol: 36 mg/dL | Status: LOW | Reference: >40
# Triglycerides: 188 mg/dL | Status: HIGH | Reference: <150
# Glucose (Fasting): 92 mg/dL | Status: NORMAL | Reference: 70–99
# HbA1c: 5.3% | Status: NORMAL | Reference: <5.7%
# Creatinine: 1.0 mg/dL | Status: NORMAL | Reference: 0.7–1.3
# eGFR: 82 mL/min | Status: NORMAL | Reference: >60
# ALT: 28 U/L | Status: NORMAL | Reference: 7–40
# AST: 25 U/L | Status: NORMAL | Reference: 10–40
# Bilirubin Total: 0.8 mg/dL | Status: NORMAL | Reference: 0.2–1.2

# %%
diet_prompt = f"""
You are a clinical nutritionist specializing in Indian dietary habits.

Based on the blood work analysis below, write:

1. A short health summary in 3 lines explaining the patient's condition in simple language.

2. A short practical Indian diet plan having ONLY two sections:

Foods to Avoid

Foods to Eat More Of

Do not include any other sections.

Blood Work Analysis:

{extracted_values}
"""

diet_response = llm.invoke(diet_prompt)

print("\n=== STAGE 2: HEALTH SUMMARY & DIET PLAN ===")
print(diet_response.content)
# Out:
# === STAGE 2: HEALTH SUMMARY & DIET PLAN ===
# Here is your health summary and diet plan:
#
# ---
#
# **1. Health Summary**
#
# Your blood tests show high levels of "bad" cholesterol and triglycerides, along with low "good" cholesterol. This pattern suggests an increased risk for heart health issues. Thankfully, simple and practical changes to your Indian diet can help improve these numbers.
#
# ---
#
# **2. Indian Diet Plan**
#
# **Foods to Avoid**
#
# *   **Deep-fried snacks:** Samosas, pakoras, puri, vada, kachori, jalebi, and other fried items.
# *   **High-fat dairy:** Full-fat milk, butter, excessive ghee, mawa, and full-fat paneer.
# *   **Processed and sugary foods:** Biscuits, namkeens, packaged sweets (mithai), sugary drinks, and foods made with *dalda* (vanaspati ghee).
# *   **Red and organ meats:** Mutton, buffalo meat, and liver.
# *   **Excessive refined carbohydrates:** White bread, maida-based products, and polished white rice in large quantities.
#
# **Foods to Eat More Of**
#
# *   **Whole grains:** Oats, brown rice, whole wheat roti/chapati, bajra, jowar, ragi.
# *   **Lentils and legumes:** All varieties of dals (toor, moong, masoor, chana), rajma, chole, lobia.
# *   **Abundant vegetables:** All fresh vegetables, especially green leafy vegetables like spinach, fenugreek, and mustard greens.
# *   **Fresh fruits:** A variety of seasonal fruits daily.
# *   **Lean protein sources:** Fish (especially fatty fish like mackerel or sardine if available), skinless chicken, eggs, tofu, and low-fat paneer or curd.
# *   **Healthy fats in moderation:** Mustard oil, groundnut oil, or a small amount of olive oil for cooking. Include a handful of nuts (almonds, walnuts) and seeds (flaxseeds, chia seeds).
# *   **Herbs and spices:** Incorporate turmeric, ginger, garlic, fenugreek, and other common Indian spices generously in your cooking.
